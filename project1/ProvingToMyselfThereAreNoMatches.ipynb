# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
loc_song_select = """SELECT
                    -- song_id
                    songs.song_id
                    -- artist_id
                   ,songs.artist_id
                FROM
                    songs
                    JOIN artists
                        ON songs.artist_id = artists.artist_id
                WHERE
                    songs.title = %s
                    AND
                    artists.name = %s
                    AND
                    songs.duration = %s;
"""

# %%
cur.execute("""SELECT songs.title, artists.name, songs.duration FROM songs JOIN artists ON songs.artist_id = artists.artist_id;""")
songs = pd.DataFrame(cur.fetchall())
songs.head()
# Out:
#                                  0  \
# 0      Kutt Free (DJ Volume Remix)
# 1  Sono andati? Fingevo di dormire
# 2   A Higher Place (Album Version)
# 3                        Ten Tonne
# 4                Jenny Take a Ride
#
#                                                    1          2
# 0                                               Jinx  407.37914
# 1  Montserrat Caballé;Placido Domingo;Vicente Sar...  511.16363
# 2                                          Tom Petty  236.17261
# 3                                     Chase & Status  337.68444
# 4                                        Mitch Ryder  207.43791

# %%
cur.execute(loc_song_select, ('Kutt Free (DJ Volume Remix)', 'Jinx', 407.37914))
test = cur.fetchone()
test
# Out:
# ('SOFNOQK12AB01840FC', 'ARNNKDK1187B98BBD5')

# %% [markdown]
# # If I only query for songs that are in the songs database, I can get matches for song_id and artist_id

# %%
for i, song in songs.iterrows():
    print(song)
    s = song[0]
    a = song[1]
    l = song[2]
    query_params = (s, a, l)
    print(query_params)
    cur.execute(loc_song_select, query_params)
    results = cur.fetchall()
    for r in results:
        print(r,'\n')
# Out:
# 0    Kutt Free (DJ Volume Remix)
# 1                           Jinx
# 2                        407.379
# Name: 0, dtype: object
# ('Kutt Free (DJ Volume Remix)', 'Jinx', 407.37914)
# ('SOFNOQK12AB01840FC', 'ARNNKDK1187B98BBD5')
#
# 0                      Sono andati? Fingevo di dormire
# 1    Montserrat Caballé;Placido Domingo;Vicente Sar...
# 2                                              511.164
# Name: 1, dtype: object
# ('Sono andati? Fingevo di dormire', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', 511.16363)
# ('SOBAYLL12A8C138AF9', 'ARDR4AC1187FB371A1')
#
# 0    A Higher Place (Album Version)
# 1                         Tom Petty
# 2                           236.173
# Name: 2, dtype: object
# ('A Higher Place (Album Version)', 'Tom Petty', 236.17261)
# ('SOFFKZS12AB017F194', 'ARBEBBY1187B9B43DB')
#
# 0         Ten Tonne
# 1    Chase & Status
# 2           337.684
# Name: 3, dtype: object
# ('Ten Tonne', 'Chase & Status', 337.68444)
# ('SOGVQGJ12AB017F169', 'AR62SOJ1187FB47BB5')
#
# 0    Jenny Take a Ride
# 1          Mitch Ryder
# 2              207.438
# Name: 4, dtype: object
# ('Jenny Take a Ride', 'Mitch Ryder', 207.43791)
# ('SOXILUQ12A58A7C72A', 'ARP6N5A1187B99D1A3')
#
# 0                 Got My Mojo Workin
# 1    Pucho & His Latin Soul Brothers
# 2                            338.233
# Name: 5, dtype: object
# ('Got My Mojo Workin', 'Pucho & His Latin Soul Brothers', 338.23302)
# ('SOLEYHO12AB0188A85', 'ARAGB2O1187FB3A161')
#
# 0    Wild Rose (Back 2 Basics Mix)
# 1                   Bombay Rockers
# 2                          230.713
# Name: 6, dtype: object
# ('Wild Rose (Back 2 Basics Mix)', 'Bombay Rockers', 230.71302)
# ('SOBKWDJ12A8C13B2F3', 'AR36F9J1187FB406F1')
#
# 0    Loaded Like A Gun
# 1           Steel Rain
# 2              173.191
# Name: 7, dtype: object
# ('Loaded Like A Gun', 'Steel Rain', 173.19138)
# ('SOOJPRH12A8C141995', 'ARBGXIG122988F409D')
#
# 0    Get Your Head Stuck On Your Neck
# 1                        Soul Mekanik
# 2                             45.6616
# Name: 8, dtype: object
# ('Get Your Head Stuck On Your Neck', 'Soul Mekanik', 45.66159)
# ('SOPEGZN12AB0181B3D', 'AREDL271187FB40F44')
#
# 0    Clementina Santafè
# 1              Gloriana
# 2               153.338
# Name: 9, dtype: object
# ('Clementina Santafè', 'Gloriana', 153.33832)
# ('SOQOTLQ12AB01868D0', 'ARGCY1Y1187B9A4FA5')
#
# 0    Rumba De Barcelona
# 1           Los Manolos
# 2               218.383
# Name: 10, dtype: object
# ('Rumba De Barcelona', 'Los Manolos', 218.38322)
# ('SOBCOSW12A8C13D398', 'AR7SMBG1187B9B9066')
#
# 0    Sonnerie lalaleulé hi houuu
# 1                     Blingtones
# 2                         29.544
# Name: 11, dtype: object
# ('Sonnerie lalaleulé hi houuu', 'Blingtones', 29.54404)
# ('SOTCKKY12AB018A141', 'ARGSAFR1269FB35070')
#
# 0    Living Hell
# 1     Bitter End
# 2        282.435
# Name: 12, dtype: object
# ('Living Hell', 'Bitter End', 282.43546)
# ('SOFCHDR12AB01866EF', 'AREVWGE1187B9B890A')
#
# 0    City Slickers
# 1     Marc Shaiman
# 2          149.864
# Name: 13, dtype: object
# ('City Slickers', 'Marc Shaiman', 149.86404)
# ('SOINLJW12A8C13314C', 'AR8IEZO1187B99055E')
#
# 0     Native Soul
# 1    Danilo Perez
# 2         197.198
# Name: 14, dtype: object
# ('Native Soul', 'Danilo Perez', 197.19791)
# ('SONSKXP12A8C13A2C9', 'AR0IAWL1187B9A96D0')
#
# 0      Intro
# 1    40 Grit
# 2    75.6763
# Name: 15, dtype: object
# ('Intro', '40 Grit', 75.67628)
# ('SOGDBUF12A8C140FAA', 'AR558FS1187FB45658')
#
# 0    Streets On Fire (Explicit Album Version)
# 1                                 Lupe Fiasco
# 2                                      279.98
# Name: 16, dtype: object
# ('Streets On Fire (Explicit Album Version)', 'Lupe Fiasco', 279.97995)
# ('SOWQTQZ12A58A7B63E', 'ARPFHN61187FB575F6')
#
# 0    Music is what we love
# 1                    Wilks
# 2                  261.511
# Name: 17, dtype: object
# ('Music is what we love', 'Wilks', 261.51138)
# ('SOLYIBD12A8C135045', 'AR051KA1187B98B2FF')
#
# 0         Midnight Star
# 1    Luna Orbit Project
# 2               335.516
# Name: 18, dtype: object
# ('Midnight Star', 'Luna Orbit Project', 335.51628)
# ('SOSWKAV12AB018FC91', 'ARULZCI1241B9C8611')
#
# 0      Prognosis
# 1    Steve Morse
# 2        363.859
# Name: 19, dtype: object
# ('Prognosis', 'Steve Morse', 363.85914)
# ('SODAUVL12A8C13D184', 'ARWB3G61187FB49404')
#
# 0    The Ballad Of Sleeping Beauty
# 1                Sophie B. Hawkins
# 2                          305.162
# Name: 20, dtype: object
# ('The Ballad Of Sleeping Beauty', 'Sophie B. Hawkins', 305.162)
# ('SONWXQJ12A8C134D94', 'ARNF6401187FB57032')
#
# 0    Der Kleine Dompfaff
# 1            Line Renaud
# 2                 152.92
# Name: 21, dtype: object
# ('Der Kleine Dompfaff', 'Line Renaud', 152.92036)
# ('SOUPIRU12A6D4FA1E1', 'ARJIE2Y1187B994AB7')
#
# 0    Harajuku Girls
# 1      Gwen Stefani
# 2            290.56
# Name: 22, dtype: object
# ('Harajuku Girls', 'Gwen Stefani', 290.55955)
# ('SORRZGD12A6310DBC3', 'ARVBRGZ1187FB4675A')
#
# 0    A Whiter Shade Of Pale (Live @ Fillmore West)
# 1                                      King Curtis
# 2                                          326.008
# Name: 23, dtype: object
# ('A Whiter Shade Of Pale (Live @ Fillmore West)', 'King Curtis', 326.00771)
# ('SODREIN12A58A7F2E5', 'ARLTWXK1187FB5A3F8')
#
# 0    Erica (2005 Digital Remaster)
# 1                    Eddie Calvert
# 2                          138.631
# Name: 24, dtype: object
# ('Erica (2005 Digital Remaster)', 'Eddie Calvert', 138.63138)
# ('SOBBXLX12A58A79DDA', 'AREDBBQ1187B98AFF5')
#
# 0    I Hold Your Hand In Mine [Live At Royal Albert...
# 1                                             Tiny Tim
# 2                                              43.3628
# Name: 25, dtype: object
# ('I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'Tiny Tim', 43.36281)
# ('SOAOIBZ12AB01815BE', 'ARPBNLO1187FB3D52F')
#
# 0                 Baby Come To Me
# 1    Kenny G featuring Daryl Hall
# 2                          236.93
# Name: 26, dtype: object
# ('Baby Come To Me', 'Kenny G featuring Daryl Hall', 236.93016)
# ('SOZHPGD12A8C1394FE', 'AR9AWNF1187B9AB0B4')
#
# 0        Wessex Loses a Bride
# 1    Nick Ingman;Gavyn Wright
# 2                     111.621
# Name: 27, dtype: object
# ('Wessex Loses a Bride', 'Nick Ingman;Gavyn Wright', 111.62077)
# ('SODUJBS12A8C132150', 'ARI2JSK1187FB496EF')
#
# 0    It Wont Be Christmas
# 1            David Martin
# 2                 241.475
# Name: 28, dtype: object
# ('It Wont Be Christmas', 'David Martin', 241.47546)
# ('SOTTDKS12AB018D69B', 'ARMBR4Y1187B9990EB')
#
# 0    OAKtown
# 1     Casual
# 2    259.448
# Name: 29, dtype: object
# ('OAKtown', 'Casual', 259.44771)
# ('SOQLGFP12A58A7800E', 'ARD7TVE1187B99BFB1')
#
# 0    Salt In NYC
# 1         Trafik
# 2        424.124
# Name: 30, dtype: object
# ('Salt In NYC', 'Trafik', 424.12363)
# ('SOQVMXR12A81C21483', 'ARKULSX1187FB45F84')
#
# 0    Knocked Out Of The Park
# 1                 John Davis
# 2                     183.17
# Name: 31, dtype: object
# ('Knocked Out Of The Park', 'John Davis', 183.17016)
# ('SOMVWWT12A58A7AE05', 'ARQ9BO41187FB5CF1F')
#
# 0    Larger Than Life
# 1     Backstreet Boys
# 2             236.251
# Name: 32, dtype: object
# ('Larger Than Life', 'Backstreet Boys', 236.25098)
# ('SOPVXLX12A8C1402D5', 'AR3JMC51187B9AE49D')
#
# 0        Den Pai Alo
# 1    Christos Dantis
# 2            243.826
# Name: 33, dtype: object
# ('Den Pai Alo', 'Christos Dantis', 243.82649)
# ('SOSLAVG12A8C13397F', 'AROGWRA122988FEE45')
#
# 0    Blessed Assurance
# 1                 Glad
# 2              270.602
# Name: 34, dtype: object
# ('Blessed Assurance', 'Glad', 270.602)
# ('SOTUKVB12AB0181477', 'AR7ZKHQ1187B98DD73')
#
# 0    Kassie Jones
# 1    Alice Stuart
# 2         220.786
# Name: 35, dtype: object
# ('Kassie Jones', 'Alice Stuart', 220.78649)
# ('SOBEBDG12A58A76D60', 'ARI3BMM1187FB4255E')
#
# 0    Broken-Down Merry-Go-Round
# 1                  Jimmy Wakely
# 2                       151.849
# Name: 36, dtype: object
# ('Broken-Down Merry-Go-Round', 'Jimmy Wakely', 151.84934)
# ('SOWTBJW12AC468AC6E', 'ARQGYP71187FB44566')
#
# 0    Tonight Will Be Alright
# 1              Lionel Richie
# 2                    307.382
# Name: 37, dtype: object
# ('Tonight Will Be Alright', 'Lionel Richie', 307.3824)
# ('SOBONFF12A6D4F84D8', 'ARIK43K1187B9AE54C')
#
# 0    Caught In A Dream
# 1                Tesla
# 2              290.298
# Name: 38, dtype: object
# ('Caught In A Dream', 'Tesla', 290.29832)
# ('SOXLBJT12A8C140925', 'ARYKCQI1187FB3B18F')
#
# 0          High Tide
# 1    Richard Souther
# 2            228.597
# Name: 39, dtype: object
# ('High Tide', 'Richard Souther', 228.5971)
# ('SOUQQEA12A8C134B1B', 'ARIG6O41187B988BDD')
#
# 0     La Culpa
# 1    Andy Andy
# 2      226.351
# Name: 40, dtype: object
# ('La Culpa', 'Andy Andy', 226.35057)
# ('SOMUYGI12AB0188633', 'ARL7K851187B99ACD2')
#
# 0    Auguri Cha Cha
# 1         Bob Azzam
# 2           191.843
# Name: 41, dtype: object
# ('Auguri Cha Cha', 'Bob Azzam', 191.84281)
# ('SORAMLE12AB017C8B0', 'ARHHO3O1187B989413')
#
# 0      Floating
# 1    Blue Rodeo
# 2       491.128
# Name: 42, dtype: object
# ('Floating', 'Blue Rodeo', 491.12771)
# ('SOHUOAP12A8AE488E9', 'ARD842G1187B997376')
#
# 0    Sohna Nee Sohna Data
# 1           Faiz Ali Faiz
# 2                 599.249
# Name: 43, dtype: object
# ('Sohna Nee Sohna Data', 'Faiz Ali Faiz', 599.24853)
# ('SOILPQQ12AB017E82A', 'AR1ZHYZ1187FB3C717')
#
# 0    Synthetic Dream
# 1          lextrical
# 2            165.694
# Name: 44, dtype: object
# ('Synthetic Dream', 'lextrical', 165.69424)
# ('SOZVMJI12AB01808AF', 'ARNPAGP1241B9C7FD4')
#
# 0    The Urgency (LP Version)
# 1                Wayne Watson
# 2                     245.211
# Name: 45, dtype: object
# ('The Urgency (LP Version)', 'Wayne Watson', 245.21098)
# ('SOKEJEJ12A8C13E0D0', 'ARC43071187B990240')
#
# 0    Setting Fire to Sleeping Giants
# 1          The Dillinger Escape Plan
# 2                            207.778
# Name: 46, dtype: object
# ('Setting Fire to Sleeping Giants', 'The Dillinger Escape Plan', 207.77751)
# ('SOBBUGU12A8C13E95D', 'ARMAC4T1187FB3FA4C')
#
# 0    I Think My Wife Is Running Around On Me (Taco ...
# 1                                           Tim Wilson
# 2                                              186.488
# Name: 47, dtype: object
# ('I Think My Wife Is Running Around On Me (Taco Hell)', 'Tim Wilson', 186.48771)
# ('SONYPOM12A8C13B2D7', 'ARDNS031187B9924F0')
#
# 0    It Makes No Difference Now
# 1              Billie Jo Spears
# 2                       133.329
# Name: 48, dtype: object
# ('It Makes No Difference Now', 'Billie Jo Spears', 133.32853)
# ('SOGXHEG12AB018653E', 'AR0RCMP1187FB3F427')
#
# 0    Superconfidential
# 1                  Clp
# 2              338.311
# Name: 49, dtype: object
# ('Superconfidential', 'Clp', 338.31138)
# ('SOZQDIU12A58A7BCF6', 'ARNTLGG11E2835DDB9')
#
# 0    Setanta matins
# 1             Elena
# 2           269.583
# Name: 50, dtype: object
# ('Setanta matins', 'Elena', 269.58322)
# ('SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4')
#
# 0    Do You Finally Need A Friend
# 1                   Terry Callier
# 2                         342.569
# Name: 51, dtype: object
# ('Do You Finally Need A Friend', 'Terry Callier', 342.56934)
# ('SOGNCJP12A58A80271', 'ARB29H41187B98F0EF')
#
# 0    Crazy Mixed Up World
# 1              Faye Adams
# 2                 156.395
# Name: 52, dtype: object
# ('Crazy Mixed Up World', 'Faye Adams', 156.39465)
# ('SOVYKGO12AB0187199', 'ARH4Z031187B9A71F2')
#
# 0                 Laws Patrolling (Album Version)
# 1    Mike Jones (Featuring CJ_ Mello & Lil' Bran)
# 2                                         173.662
# Name: 53, dtype: object
# ('Laws Patrolling (Album Version)', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 173.66159)
# ('SOOLYAZ12A6701F4A6', 'AREBBGV1187FB523D2')
#
# 0    ¿Dónde va Chichi?
# 1       Sierra Maestra
# 2              313.129
# Name: 54, dtype: object
# ('¿Dónde va Chichi?', 'Sierra Maestra', 313.12934)
# ('SOGOSOV12AF72A285E', 'ARGUVEV1187B98BA17')
#
# 0    Twist and Shout
# 1    The Shangri-Las
# 2            164.806
# Name: 55, dtype: object
# ('Twist and Shout', 'The Shangri-Las', 164.80608)
# ('SOYTPEP12AB0180E7B', 'ARAJPHH1187FB5566A')
#
# 0    Made Like This (Live)
# 1           Five Bolt Main
# 2                  225.097
# Name: 56, dtype: object
# ('Made Like This (Live)', 'Five Bolt Main', 225.09669)
# ('SOPSWQW12A6D4F8781', 'ARGIWFO1187B9B55B7')
#
# 0    The Emperor Falls
# 1          John Wesley
# 2              484.623
# Name: 57, dtype: object
# ('The Emperor Falls', 'John Wesley', 484.62322)
# ('SOLLHMX12AB01846DC', 'AR1Y2PT1187FB5B9CE')
#
# 0    James (Hold The Ladder Steady)
# 1                      SUE THOMPSON
# 2                           124.865
# Name: 58, dtype: object
# ('James (Hold The Ladder Steady)', 'SUE THOMPSON', 124.86485)
# ('SOBLGCN12AB0183212', 'AR47JEX1187B995D81')
#
# 0    Spanish Grease
# 1       Willie Bobo
# 2           168.254
# Name: 59, dtype: object
# ('Spanish Grease', 'Willie Bobo', 168.25424)
# ('SOBZBAZ12A6D4F8742', 'AROUOZZ1187B9ABE51')
#
# 0    Keepin It Real (Skit)
# 1                  Rated R
# 2                  114.782
# Name: 60, dtype: object
# ('Keepin It Real (Skit)', 'Rated R', 114.78159)
# ('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5')
#
# 0    Face the Ashes
# 1               Gob
# 2           209.606
# Name: 61, dtype: object
# ('Face the Ashes', 'Gob', 209.60608)
# ('SOFSOCN12A8C143F5D', 'ARXR32B1187FB57099')
#
# 0     Amor De Cabaret
# 1    Sonora Santanera
# 2             177.475
# Name: 62, dtype: object
# ('Amor De Cabaret', 'Sonora Santanera', 177.47546)
# ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA')
#
# 0    Insatiable (Instrumental Version)
# 1                                  Clp
# 2                              266.396
# Name: 63, dtype: object
# ('Insatiable (Instrumental Version)', 'Clp', 266.39628)
# ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9')
#
# 0    I Didn't Mean To
# 1              Casual
# 2             218.932
# Name: 64, dtype: object
# ("I Didn't Mean To", 'Casual', 218.93179)
# ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1')
#
# 0             Drop of Rain
# 1    Tweeterfriendly Music
# 2                   189.57
# Name: 65, dtype: object
# ('Drop of Rain', 'Tweeterfriendly Music', 189.57016)
# ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1')
#
# 0          Pink World
# 1    Planet P Project
# 2             269.818
# Name: 66, dtype: object
# ('Pink World', 'Planet P Project', 269.81832)
# ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B')
#
# 0    Something Girls
# 1           Adam Ant
# 2            233.404
# Name: 67, dtype: object
# ('Something Girls', 'Adam Ant', 233.40363)
# ('SONHOTT12A8C13493C', 'AR7G5I41187FB4CE6C')
#
# 0    The Moon And I (Ordinary Day Album Version)
# 1                          Jeff And Sheri Easter
# 2                                        267.702
# Name: 68, dtype: object
# ('The Moon And I (Ordinary Day Album Version)', 'Jeff And Sheri Easter', 267.7024)
# ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F')
#
# 0       Soul Deep
# 1    The Box Tops
# 2         148.035
# Name: 69, dtype: object
# ('Soul Deep', 'The Box Tops', 148.03546)
# ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3')
#
# 0    Young Boy Blues
# 1       JennyAnyKind
# 2            218.775
# Name: 70, dtype: object
# ('Young Boy Blues', 'JennyAnyKind', 218.77506)
# ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B')

# %% [markdown]
# # Now, open up a log file, loop through entries in the log file and see if any of the songs from the log file are in the songs table
#
# Note, this after processing all the songs available using etl.py. These are the same songs that would be available when trying to find artist_id and song_id during log file processing.

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files:
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
# 1         Gang Starr  Logged In     Layla      F             88  Griffin
# 2              3OH!3  Logged In     Layla      F             89  Griffin
# 3        RÃÂ¶yksopp  Logged In     Jacob      M             54    Klein
# 4         Kajagoogoo  Logged In     Layla      F             90  Griffin
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 1  151.92771  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 2  192.52200  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 3  369.81506  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  223.55546  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
#
#    registration  sessionId                                         song  \
# 0  1.540558e+12        954                            Ain't No Sunshine
# 1  1.541057e+12        984                   My Advice 2 You (Explicit)
# 2  1.541057e+12        984  My First Kiss (Feat. Ke$ha) [Album Version]
# 3  1.540558e+12        954                       The Girl and The Robot
# 4  1.541057e+12        984                                      Too Shy
#
#    status             ts                                          userAgent  \
# 0     200  1543449657796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543449690796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2     200  1543449841796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     200  1543449895796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543450033796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
#
#   userId
# 0     73
# 1     24
# 2     24
# 3     73
# 4     24

# %%
# filter by NextSong
df = df[df['page']=='NextSong']

# %% [markdown]
# # Loop through log file, first print the song name from the log file, then the row where that song is in the songs table.
# # Notice that not a single song in the log file is present in the songs database!
# # There is a mismatch between the log files and the song files. So frustrating to have spent
# # several hours troubleshooting when this possibility should have been communicated with us!

# %%
# insert songplay records
for index, row in df.iterrows():
    s = row.song
    a = row.artist
    l = row.length
    query_params = (s, a, l)
    print(s)
    print(songs[(songs[0]==s)])#&(songs[1]==a)&(songs[2]==l)])
    # get songid and artistid from song and artist tables
    cur.execute(song_select, query_params)
    results = cur.fetchone()
    print(results)
    if results:
        songid, artistid = results
    else:
        songid, artistid = s, a

    # insert songplay record
    songplay_data = (row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent,)
    print(songplay_data)
# Out:
# Ain't No Sunshine
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543449657796, '73', 'paid', "Ain't No Sunshine", 'Sydney Youngblood', 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# My Advice 2 You (Explicit)
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543449690796, '24', 'paid', 'My Advice 2 You (Explicit)', 'Gang Starr', 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# My First Kiss (Feat. Ke$ha) [Album Version]
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543449841796, '24', 'paid', 'My First Kiss (Feat. Ke$ha) [Album Version]', '3OH!3', 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# The Girl and The Robot
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543449895796, '73', 'paid', 'The Girl and The Robot', 'RÃ\x83Â¶yksopp', 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
# Too Shy
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543450033796, '24', 'paid', 'Too Shy', 'Kajagoogoo', 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# Potential
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543450256796, '24', 'paid', 'Potential', 'The Jimmy Castor Bunch', 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')
# The Great Satan (What Would Satan Do Mix)
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []
# None
# (1543450264796, '73', 'paid', 'The Great Satan (What Would Satan Do Mix)', 'Ministry', 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"')
